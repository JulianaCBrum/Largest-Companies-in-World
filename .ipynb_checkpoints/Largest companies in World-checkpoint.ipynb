# %% [markdown]
# ### Largest Companies in World
#
# This is a interesting dataset about the Largest Companies in the World, they are measured by Revenue, Profits, Assets and Market Value. It is from https://www.kaggle.com/datasets/jasmeet0516/largest-companies-in-world, and was updated one month ago.
#
# During the process of data cleaning I found some missing and duplicated values, my approach for each situation is mentioned before the corresponding codes.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import dash
from dash import dcc, html, Input, Output
import plotly.express as px

# %%
df = pd.read_csv('Largest companies in world.csv')

# %%
df.head()
# Out:
#   rank                          organizationName        country   revenue  \
# 0    1                            JPMorgan Chase  United States  179.93 B
# 1    2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  589.47 B
# 2    3                                      ICBC          China  216.77 B
# 3    4                   China Construction Bank          China  203.08 B
# 4    5                Agricultural Bank of China          China  186.14 B
#
#     profits      assets marketValue
# 0    41.8 B   3,744.3 B    399.59 B
# 1  156.36 B    660.99 B  2,055.22 B
# 2   52.47 B  6,116.82 B    203.01 B
# 3   48.25 B  4,977.48 B    172.99 B
# 4   37.92 B  5,356.86 B    141.82 B

# %%
df.tail()
# Out:
#        rank organizationName        country  revenue  profits   assets  \
# 2046  1,996       Alfa Laval         Sweden   5.35 B  489.5 M   7.82 B
# 2047  1,996              Gap  United States  15.62 B   -202 M  11.39 B
# 2048  1,996         Yes Bank          India   3.34 B   91.6 M  43.22 B
# 2049  1,999        BEKB-BCBE    Switzerland    556 M  167.1 M  42.97 B
# 2050  1,999            Ipsen         France   3.18 B  681.7 M   5.99 B
#
#      marketValue
# 2046      15.6 B
# 2047      3.17 B
# 2048       5.6 B
# 2049      2.49 B
# 2050     10.21 B

# %% [markdown]
# The code info, shows some columns with missing values. So, I dropped them.

# %%
df['country'].unique()
# Out:
# array(['United States', 'Saudi Arabia', 'China', 'United Kingdom',
#        'Japan', 'South Korea', 'France', 'Hong Kong', 'Germany', 'Canada',
#        'Taiwan', 'India', 'Spain', 'Switzerland', 'Norway', 'Brazil',
#        'Netherlands', 'Belgium', 'Italy', 'Australia', 'Ireland',
#        'Denmark', 'Mexico', 'Singapore', 'Qatar', 'Luxembourg', 'Finland',
#        'Sweden', 'Thailand', 'Poland', 'United Arab Emirates',
#        'Indonesia', 'Colombia', 'Austria', 'Turkey', 'Czech Republic',
#        'Malaysia', 'South Africa', 'Bermuda', 'Portugal', 'Kuwait',
#        'Chile', 'Israel', 'Argentina', 'Vietnam', 'Hungary',
#        'Philippines', 'Peru', 'Uruguay', 'Greece', 'Cayman Islands',
#        'Kazakhstan', 'Morocco', 'Egypt', 'Nigeria', 'Jordan', 'Oman',
#        'Pakistan'], dtype=object)

# %%
ireland_companies_count = len(df[df['country'] == 'Ireland'])
print("Number of companies in Ireland:", ireland_companies_count)
# Out:
# Number of companies in Ireland: 22

# %%
ireland_companies = df[df['country'] == 'Ireland']

# %%
ireland_companies.head(22)
# Out:
#        rank                             organizationName  country  \
# 210     160                                    Accenture  Ireland
# 222     171                                    Medtronic  Ireland
# 354     304                                          CRH  Ireland
# 386     336                                 PDD Holdings  Ireland
# 412     362                                        Eaton  Ireland
# 449     399               Johnson Controls International  Ireland
# 503     453                                          Aon  Ireland
# 682     632                           Trane Technologies  Ireland
# 785     735                              AerCap Holdings  Ireland
# 814     764                              Bank of Ireland  Ireland
# 840     790                                        Aptiv  Ireland
# 918     868                             Ryanair Holdings  Ireland
# 1058  1,008                                    AIB Group  Ireland
# 1128  1,078                        Flutter Entertainment  Ireland
# 1217  1,167                                     Experian  Ireland
# 1267  1,217                          Smurfit Kappa Group  Ireland
# 1323  1,273                                  Kerry Group  Ireland
# 1468  1,418                               ICON (Ireland)  Ireland
# 1511  1,461                           Kingspan Group PLC  Ireland
# 1722  1,670                                          DCC  Ireland
# 1881  1,831  Horizon Therapeutics Public Limited Company  Ireland
# 1990  1,938                           Seagate Technology  Ireland
#
#            revenue       profits        assets   marketValue
# 210   6.314000e+10  6.940000e+09  4.773000e+10  1.760200e+11
# 222   3.077000e+10  4.070000e+09  9.413000e+10  1.198200e+11
# 354   3.284000e+10  3.830000e+09  4.519000e+10  3.636000e+10
# 386   1.928000e+10  4.630000e+09  3.411000e+10  8.321000e+10
# 412   2.139000e+10  2.570000e+09  3.552000e+10  6.818000e+10
# 449   2.609000e+10  1.390000e+09  4.342000e+10  4.267000e+10
# 503   1.268000e+10  2.620000e+09  3.425000e+10  6.707000e+10
# 682   1.630000e+10  1.800000e+09  1.790000e+10  4.032000e+10
# 785   6.870000e+09  1.710000e+09  6.968000e+10  1.370000e+10
# 814   8.120000e+09  1.030000e+09  1.632800e+11  1.046000e+10
# 840   1.813000e+10  6.670000e+08  2.172000e+10  2.527000e+10
# 918   1.062000e+10  1.440000e+09  1.682000e+10  1.866000e+10
# 1058  3.620000e+09  7.378000e+08  1.384800e+11  1.104000e+10
# 1128  9.480000e+09 -3.720000e+08  2.464000e+10  3.444000e+10
# 1217  6.470000e+09  9.374000e+08  1.042000e+10  3.099000e+10
# 1267  1.346000e+10  9.891000e+08  1.359000e+10  9.600000e+09
# 1323  9.220000e+09  6.373000e+08  1.311000e+10  1.862000e+10
# 1468  7.820000e+09  5.100000e+08  1.729000e+10  1.555000e+10
# 1511  8.770000e+09  6.285000e+08  8.200000e+09  1.230000e+10
# 1722  2.685000e+10  4.150000e+08  1.095000e+10  6.060000e+09
# 1881  3.580000e+09  3.719000e+08  8.990000e+09  2.569000e+10
# 1990  8.410000e+09 -1.610000e+08  7.970000e+09  1.158000e+10

# %%
ireland_companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 210 to 1990
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              22 non-null     object
#  1   organizationName  22 non-null     object
#  2   country           22 non-null     object
#  3   revenue           22 non-null     float64
#  4   profits           22 non-null     float64
#  5   assets            22 non-null     float64
#  6   marketValue       22 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 1.4+ KB

# %% [markdown]
# Here, I needed to replace some object datatypes with float values in the columns Profits, Assets, MarketValue, and Revenue. Since I couldn't plot graphics using object values, the code below checks if the value is already a float, and if not, transforms it into a float.

# %% [markdown]
# This code checks if there are duplicated rows. If it has, it drops them.

# %% [markdown]
# This first graphic is to dem

# %%
# Group by 'organizationName' and 'country', summing the revenue for each company in each country
top_ireland_companie = ireland_companies.groupby(['organizationName', 'country'])['revenue'].sum().reset_index()

# Sort the DataFrame by revenue in descending order
top_ireland_companies = top_ireland_companies.sort_values(by='revenue', ascending=False)

# Select the top 10 largest companies by revenue and country
top_10_ireland_companies =top_ireland_companies.head(10)

# Plot the top 10 largest companies by revenue and country
plt.figure(figsize=(10, 6))
plt.barh(top_10_ireland_companies['organizationName'],
         top_10_ireland_companies['revenue'], color='skyblue')
plt.xlabel('Revenue (USD)')
plt.ylabel('Company - Country')
plt.title('Top 10 Ireland Companies by Revenue')
plt.gca().invert_yaxis()  # Invert y-axis to show the highest revenue at the top
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Group by 'organizationName' and 'country', summing the revenue for each company in each country
top_companies_by_country = df.groupby(['organizationName', 'country'])['profits'].sum().reset_index()

# Sort the DataFrame by revenue in descending order
top_companies_by_country = top_companies_by_country.sort_values(by='profits', ascending=False)

# Select the top 10 largest companies by revenue and country
top_10_by_country = top_companies_by_country.head(10)

# Plot the top 10 largest companies by revenue and country
plt.figure(figsize=(10, 6))
plt.barh(top_10_by_country['organizationName'] + ' - ' + top_10_by_country['country'],
         top_10_by_country['profits'], color='skyblue')
plt.xlabel('Profits (USD)')
plt.ylabel('Company - Country')
plt.title('Top 10 Largest Companies by Profits and Country')
plt.gca().invert_yaxis()  # Invert y-axis to show the highest revenue at the top
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Group by 'organizationName' and 'country', summing the revenue for each company in each country
top_companies_by_country = df.groupby(['organizationName', 'country'])['assets'].sum().reset_index()

# Sort the DataFrame by revenue in descending order
top_companies_by_country = top_companies_by_country.sort_values(by='assets', ascending=False)

# Select the top 10 largest companies by revenue and country
top_10_by_country = top_companies_by_country.head(10)

# Plot the top 10 largest companies by revenue and country
plt.figure(figsize=(10, 6))
plt.barh(top_10_by_country['organizationName'] + ' - ' + top_10_by_country['country'],
         top_10_by_country['assets'], color='skyblue')
plt.xlabel('Assets (USD)')
plt.ylabel('Company - Country')
plt.title('Top 10 Largest Companies by Profits and Assets')
plt.gca().invert_yaxis()  # Invert y-axis to show the highest revenue at the top
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Group by 'organizationName' and 'country', summing the revenue for each company in each country
top_companies_by_country = df.groupby(['organizationName', 'country'])['marketValue'].sum().reset_index()

# Sort the DataFrame by revenue in descending order
top_companies_by_country = top_companies_by_country.sort_values(by='marketValue', ascending=False)

# Select the top 10 largest companies by revenue and country
top_10_by_country = top_companies_by_country.head(10)

# Plot the top 10 largest companies by revenue and country
plt.figure(figsize=(10, 6))
plt.barh(top_10_by_country['organizationName'] + ' - ' + top_10_by_country['country'],
         top_10_by_country['marketValue'], color='skyblue')
plt.xlabel('Market_Values (USD)')
plt.ylabel('Company - Country')
plt.title('Top 10 Largest Companies by Profits and Market_Values')
plt.gca().invert_yaxis()  # Invert y-axis to show the highest revenue at the top
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd

# Assuming 'df' is your DataFrame

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("Largest Companies Dashboard"),
    dcc.Dropdown(
        id='company-dropdown',
        options=[{'label': company, 'value': company} for company in ireland_companies['organizationName']],
        value=ireland_companies['organizationName'].iloc[0]  # Default value
    ),
    dcc.Graph(id='company-indicators-graph')
])

# Define callback to update the graph based on dropdown selection
@app.callback(
    Output('company-indicators-graph', 'figure'),
    [Input('company-dropdown', 'value')]
)
def update_graph(selected_company):
    selected_data = ireland_companies[ireland_companies['organizationName'] == selected_company]
    
    # Create a bar chart showing profit, revenue, assets, and market value
    fig = {
        'data': [
            {'x': ['Profit', 'Revenue', 'Assets', 'Market Value'],
             'y': [selected_data['profits'].values[0], selected_data['revenue'].values[0],
                   selected_data['assets'].values[0], selected_data['marketValue'].values[0]],
             'type': 'bar'}
        ],
        'layout': {
            'title': f'{selected_company} Indicators',
            'yaxis': {'title': 'Amount'}
        }
    }
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
